# %% [markdown]
# # Check Devbox
#
# This notebook provides an overview of the installed software package versions.
#
# ### Overview of Installed Software Packages

# %%
# %load_ext watermark
# %watermark -v -m -p pip,notebook,jupyterhub,jupyterlab,ipykernel,numpy,scipy,pandas,h5py,matplotlib,seaborn,sklearn,scikit-learn,plotly,keras,sqlalchemy,statsmodels,imutils
# Out:
# 2025-12-01 23:47:03.478947: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-01 23:47:03.494183: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-01 23:47:03.997100: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-01 23:47:07.568050: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-01 23:47:07.572380: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Python implementation: CPython
# Python version       : 3.13.5
# IPython version      : 9.7.0
#
# pip         : 25.3
# notebook    : 7.5.0
# jupyterhub  : 5.4.2
# jupyterlab  : 4.5.0
# ipykernel   : 7.1.0
# numpy       : 2.2.6
# scipy       : 1.16.3
# pandas      : 2.3.3
# h5py        : 3.15.1
# matplotlib  : 3.10.7
# seaborn     : 0.13.2
# sklearn     : 1.7.2
# scikit-learn: 1.7.2
# plotly      : 6.5.0
# keras       : 3.12.0
# sqlalchemy  : 2.0.44
# statsmodels : 0.14.5
# imutils     : 0.5.4
#
# Compiler    : GCC 14.2.0
# OS          : Linux
# Release     : 6.6.87.2-microsoft-standard-WSL2
# Machine     : x86_64
# Processor   :
# CPU cores   : 32
# Architecture: 64bit

# %% [markdown]
# ## List Python Packages

# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   2.3.1
# aiohappyeyeballs          2.6.1
# aiohttp                   3.13.2
# aiosignal                 1.4.0
# alembic                   1.17.2
# alpha_vantage             3.0.0
# annotated-types           0.7.0
# anyio                     4.12.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# astroid                   4.0.2
# asttokens                 3.0.1
# astunparse                1.6.3
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.3.0
# Bottleneck                1.6.0
# cattrs                    25.3.0
# certifi                   2025.11.12
# certipy                   0.2.2
# cffi                      2.0.0
# charset-normalizer        3.4.4
# comm                      0.2.3
# contourpy                 1.3.3
# cryptography              46.0.3
# curl_cffi                 0.13.0
# cycler                    0.12.1
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# dill                      0.4.0
# docutils                  0.22.3
# duckdb                    1.4.2
# et_xmlfile                2.0.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# financedatabase           2.3.1
# financetoolkit            2.0.6
# finnhub-python            2.4.25
# flatbuffers               25.9.23
# fonttools                 4.61.0
# fqdn                      1.5.1
# frozendict                2.4.7
# frozenlist                1.8.0
# gast                      0.7.0
# google-pasta              0.2.0
# graphviz                  0.21
# greenlet                  3.2.4
# grpcio                    1.76.0
# h11                       0.16.0
# h5py                      3.15.1
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# importlib_metadata        8.7.0
# imutils                   0.5.4
# inflection                0.5.1
# ipykernel                 7.1.0
# ipython                   9.7.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# isort                     7.0.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# joblib                    1.5.2
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.3
# jupyterhub                5.4.2
# jupyterlab                4.5.0
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# keras                     3.12.0
# kiwisolver                1.4.9
# lark                      1.3.1
# libclang                  18.1.1
# llvmlite                  0.45.1
# lxml                      6.0.2
# Mako                      1.3.10
# Markdown                  3.10
# markdown-it-py            4.0.0
# MarkupSafe                3.0.3
# matplotlib                3.10.7
# matplotlib-inline         0.2.1
# mccabe                    0.7.0
# mdurl                     0.1.2
# mistune                   3.1.4
# ml_dtypes                 0.5.4
# more-itertools            10.8.0
# MouseInfo                 0.1.3
# multidict                 6.7.0
# multitasking              0.0.12
# namex                     0.1.0
# narwhals                  2.12.0
# Nasdaq-Data-Link          1.0.4
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.5.0
# notebook_shim             0.2.4
# numba                     0.62.1
# numexpr                   2.14.1
# numpy                     2.2.6
# oauthlib                  3.3.1
# odfpy                     1.4.1
# opencv-python-headless    4.12.0.88
# openpyxl                  3.1.5
# opt_einsum                3.4.0
# optree                    0.18.0
# packaging                 25.0
# pamela                    1.2.0
# pandas                    2.3.3
# pandas-datareader         0.10.0
# pandocfilters             1.5.1
# parso                     0.8.5
# patsy                     1.0.2
# peewee                    3.18.3
# pexpect                   4.9.0
# pillow                    12.0.0
# pip                       25.3
# platformdirs              4.5.0
# plotly                    6.5.0
# prometheus_client         0.23.1
# prompt_toolkit            3.0.52
# propcache                 0.4.1
# protobuf                  6.33.1
# psutil                    7.1.3
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# PyAutoGUI                 0.9.54
# pycparser                 2.23
# pydantic                  2.12.5
# pydantic_core             2.41.5
# PyGetWindow               0.0.9
# Pygments                  2.19.2
# pylint                    4.0.3
# PyMsgBox                  2.0.1
# pyparsing                 3.2.5
# pyperclip                 1.11.0
# PyRect                    0.2.0
# PyScreeze                 1.0.1
# python-calamine           0.6.1
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# python3-xlib              0.15
# pytweening                1.2.0
# pytz                      2025.2
# pyxlsb                    1.0.10
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# requests-cache            1.2.1
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rich                      14.2.0
# rpds-py                   0.29.0
# scikit-learn              1.7.2
# scipy                     1.16.3
# seaborn                   0.13.2
# Send2Trash                1.8.3
# setuptools                80.9.0
# six                       1.17.0
# soupsieve                 2.8
# SQLAlchemy                2.0.44
# stack-data                0.6.3
# statsmodels               0.14.5
# tensorboard               2.20.0
# tensorboard-data-server   0.7.2
# tensorflow                2.20.0
# termcolor                 3.2.0
# terminado                 0.18.1
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tomlkit                   0.13.3
# tornado                   6.5.2
# tqdm                      4.67.1
# traitlets                 5.14.3
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# tzdata                    2025.2
# uri-template              1.3.0
# url-normalize             2.2.1
# urllib3                   2.5.0
# uv                        0.9.13
# watermark                 2.5.0
# wcwidth                   0.2.14
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# websockets                15.0.1
# Werkzeug                  3.1.4
# wheel                     0.45.1
# widgetsnbextension        4.0.15
# wrapt                     2.0.1
# xarray                    2025.11.0
# xlrd                      2.0.2
# xlsxwriter                3.2.9
# yarl                      1.22.0
# yfinance                  0.2.66
# zipp                      3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Memory

# %%
# !free -m
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:           31666        5914       22947          14        3186       25751
# Swap:           8192           0        8192

# %% [markdown]
# ## Testing DuckDB

# %%
import duckdb
cursor = duckdb.connect()
print(cursor.execute('SELECT 42').fetchall())
# Out:
# [(42,)]

# %% [markdown]
# ## List Magic Commands
#
# Please read the documentation to learn more about the built-in magic commands of the IPython kernel: [IPython Built-in Magic Commands](https://ipython.readthedocs.io/en/stable/interactive/magics.html#built-in-magic-commands).

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %watermark  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.
